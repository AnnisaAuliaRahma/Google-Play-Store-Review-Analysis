# %%
import json
import pandas as pd
from tqdm import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter

from google_play_scraper import Sort,reviews, app

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'


sns.set(style = 'whitegrid', palette = 'muted', font_scale=1.2)

# %%
app_packages = [
    'id.flip'
    #'com.google.android.apps.meetings&hl=in&gl=US'
    #'id.flip&hl=in&gl=US&showAllReviews=true'
]

# %%
app_infos = []

for ap in tqdm(app_packages):
    info = app(ap, lang = 'id', country='id')
    del info['comments']
    app_infos.append(info)
# Out:
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:06<00:00, 66.85s/it]

# %%
def print_json(json_object):
    json_str = json.dumps(
        json_object,
        indent=2,
        sort_keys=True,
        default=str
    )
    print(highlight(json_str,JsonLexer(),TerminalFormatter()))

# %%
print_json(app_infos[0])
# Out:
# {
#   "adSupported": null,
#   "androidVersion": "5.0",
#   "androidVersionText": "5.0 dan yang lebih tinggi",
#   "appId": "id.flip",
#   "containsAds": false,
#   "contentRating": "Rating 3+",
#   "contentRatingDescription": null,
#   "currency": "IDR",
#   "description": "<b>Transfer antarbank gratis? top up e-wallet tanpa biaya? atau transfer uang ke luar negeri biaya murah? Pakai Flip!</b>\r\n\r\n<b>Dengan Flip, kamu bisa hemat hingga jutaan rupiah per bulan.</b> Kamu bisa transfer gratis dari dan ke bank berikut ini: <b>BCA, BNI, Bank Mandiri, BRI, CIMB Niaga, BTPN, Jenius, BTPN Wow, BRI Syariah, BNI Syariah, Mandiri Syariah (Bank Syariah Indonesia / BSI), CIMB Niaga Syariah, Muamalat, Permata, Permata Syariah, Digibank by DBS Indonesia, dan ke 100 bank lainnya.</b>\r\n\r\nTidak hanya bisa transfer uang ke beda bank, kamu juga bisa melakukan transaksi lainnya dengan biaya yang super murah, bahkan dengan harga agen!\r\n\r\nMulai dari <b>top up e-wallet, transfer uang ke luar negeri, beli pulsa dan paket data, hingga isi token listrik</b> bisa dilakukan dengan biaya terjangkau.\r\n\r\nSelain itu, kamu juga bisa kirim uang ke banyak rekening atau top up langsung ke banyak e-wallet cukup dengan 1 kali transaksi. Jadi makin praktis kan?\r\n\r\nAplikasi Flip juga <b>aman karena sudah terlisensi Bank Indonesia</b>. Hal ini membuat Flip dipercaya jutaan pengguna di Indonesia.\r\n\r\nBeberapa kemudahan transfer pakai Flip:\r\n\r\n\u2705 Transfer gratis dari dan ke bank-bank terbesar di Indonesia\r\n\u2705 Kirim uang ke banyak rekening/e-wallet dalam 1 kali transaksi\r\n\u2705 Pengecekan nomor rekening tujuan otomatis\r\n\u2705 Bisa transfer mulai dari Rp10.000\r\n\u2705 Transfer gratis tanpa kuota bulanan\r\n\u2705 Penerima dana tidak perlu memiliki akun Flip\r\n\u2705 Setelah transaksi terkirim, Flip akan mengirimkan bukti transfer melalui aplikasi dan email\r\n\u2705 Terdapat in-app live chat yang siap membantu jika kamu mengalami kesulitan\r\n\u2705 Terdapat fitur \"Ajak Teman\" yang bisa membuatmu cuan banyak hanya dengan mengajak teman berhemat dengan Flip\r\n\u2705 Bukan hanya itu, Flip juga mengenkripsi dan memberikan keamanan ganda untuk data pribadi kamu\r\n\r\nSelain transfer antarbank gratis, ini fitur lainnya yang bisa membantu kamu berhemat:\r\n\r\n\ud83d\udc5b Top Up saldo e-wallet DANA, GoPay, OVO dan ShopeePay tanpa biaya admin!\r\n\ud83c\udf0f Flip Globe, kirim uang ke luar negeri dengan biaya flat mulai dari Rp45.000 tanpa biaya tambahan tersembunyi.\r\n\u26a1 Layanan PPOB untuk isi pulsa, beli kuota atau paket data, dan beli token listrik dengan harga agen. Selain itu, bisa juga digunakan untuk pembayaran tagihan listrik pascabayar.\r\n\r\nUntuk memudahkan pemakaian, gunakan Flip bersama aplikasi di bawah ini:\r\n\r\n- BCA Mobile\r\n- BNI Mobile Banking (Berlaku juga untuk BNI Syariah Mobile Banking)\r\n- BRImo BRI (BRI Mobile Banking)\r\n- Livin by Mandiri (Mandiri Online / Mandiri Mobile Banking)\r\n- Muamalat DIN (Muamalat Mobile)\r\n- Go Mobile / OCTO Mobile by CIMB Niaga\r\n- BRIS Online\r\n- Mandiri Syariah Mobile (BSI Mobile)\r\n- PermataMobile X\r\n- Jenius, BTPN, BTPN Wow.\r\n\r\nSelain menggunakan layanan mobile banking, kamu juga bisa transfer ke Flip melalui ATM atau layanan e-banking lainnya seperti internet banking atau online banking dari bank yang didukung oleh Flip, seperti: IB BRI (Internet Banking BRI), BNI Internet Banking, OCTO Clicks (CIMB Clicks Indonesia), dll.\r\n\r\n\u26a0\ufe0f<b>Catatan Penting</b>\u26a0\ufe0f\r\n\r\n- Flip sudah melayani pengiriman ke beberapa bank swasta seperti Bank Mega, Bank Jago, Citibank dan lainnya. Serta bank daerah di Indonesia seperti Bank Aceh, Bank DKI, Bank Jateng, dan lainnya.\r\n\r\n- Hindari pengiriman ke Flip melalui e-wallet Gopay, OVO, DANA, LinkAja, atau layanan lain seperti BRILink atau Fasapay.\r\n\r\n- Pembelian pulsa dan paket data bisa ditujukan ke nomor dari salah satu provider ini: Telkomsel, Indosat Ooredoo, XL, Tri, Smartfren, Axis, dan By.U (khusus prabayar).\r\n\r\n- Flip Globe bisa digunakan untuk mengirim uang dari Indonesia ke negara berikut: Malaysia, Singapura, Korea Selatan, Jepang, India, Thailand, China, Filipina, Australia, Hong Kong, Inggris, dan Turki.\r\n\r\n- Flip Globe memil ...
#   "descriptionHTML": "<b>Transfer antarbank gratis? top up e-wallet tanpa biaya? atau transfer uang ke luar negeri biaya murah? Pakai Flip!</b><br><br><b>Dengan Flip, kamu bisa hemat hingga jutaan rupiah per bulan.</b> Kamu bisa transfer gratis dari dan ke bank berikut ini: <b>BCA, BNI, Bank Mandiri, BRI, CIMB Niaga, BTPN, Jenius, BTPN Wow, BRI Syariah, BNI Syariah, Mandiri Syariah (Bank Syariah Indonesia / BSI), CIMB Niaga Syariah, Muamalat, Permata, Permata Syariah, Digibank by DBS Indonesia, dan ke 100 bank lainnya.</b><br><br>Tidak hanya bisa transfer uang ke beda bank, kamu juga bisa melakukan transaksi lainnya dengan biaya yang super murah, bahkan dengan harga agen!<br><br>Mulai dari <b>top up e-wallet, transfer uang ke luar negeri, beli pulsa dan paket data, hingga isi token listrik</b> bisa dilakukan dengan biaya terjangkau.<br><br>Selain itu, kamu juga bisa kirim uang ke banyak rekening atau top up langsung ke banyak e-wallet cukup dengan 1 kali transaksi. Jadi makin praktis kan?<br
#   "developerEmail": "hello@flip.id",
#   "developerId": "Flip.id",
#   "developerInternalID": "6535008663750970381",
#   "developerWebsite": "https://flip.id",
#   "editorsChoice": false,
#   "free": true,
#   "genre": "Keuangan",
#   "genreId": "FINANCE",
#   "headerImage": "https://play-lh.googleusercontent.com/Ddmuma79XO3qj8xzEPgjiQXeRZG_MHwuBGiolOXdpQgw6ST1q0s57vRoRNFm-FCQ_bM",
#   "histogram": [
#     15705,
#     4276,
#     6790,
#     27512,
#     291379
#   ],
#   "icon": "https://play-lh.googleusercontent.com/rsVpOOx0805dxUELeplBw0UVlEwz8JRZ-X0lutWPwIaNfNGlJwQ75MBkQ2CdnzSTtOo",
#   "inAppProductPrice": null,
#   "installs": "5.000.000+",
#   "minInstalls": 5000000,
#   "moreByDeveloper": null,
#   "offersIAP": false,
#   "originalPrice": null,
#   "price": 0,
#   "privacyPolicy": "https://flip.id/privacy-policy",
#   "ratings": 345662,
#   "recentChanges": "Kakak tau gak? Flip diam-diam selalu dengerin semua masukan dari Kakak lho!\r\nMakanya Flip mau kasih tau kalau...\r\n\r\nKalau setelah update nanti, Kakak bisa isi pulsa, paket data dan produk digital lainnya serta kirim uang ke luar negeri pake Flip Globe tanpa perlu verifikasi email dulu, asik kan?\r\n\r\nSelain itu Kakak juga bisa transfer berkali-kali ke banyak rekening dan top up ke banyak e-wallet tanpa perlu nunggu lagi, hepi gak tuh?\r\n\r\nJadi, update sekarang ya :)",
#   "recentChangesHTML": "Kakak tau gak? Flip diam-diam selalu dengerin semua masukan dari Kakak lho!<br>Makanya Flip mau kasih tau kalau...<br><br>Kalau setelah update nanti, Kakak bisa isi pulsa, paket data dan produk digital lainnya serta kirim uang ke luar negeri pake Flip Globe tanpa perlu verifikasi email dulu, asik kan?<br><br>Selain itu Kakak juga bisa transfer berkali-kali ke banyak rekening dan top up ke banyak e-wallet tanpa perlu nunggu lagi, hepi gak tuh?<br><br>Jadi, update sekarang ya :)",
#   "released": "10 Jan 2017",
#   "reviews": 160510,
#   "sale": false,
#   "saleText": null,
#   "saleTime": null,
#   "score": 4.6622434,
#   "screenshots": [
#     "https://play-lh.googleusercontent.com/gKQepcz66XE-iY68AKAOyHaLh3K3dO81wyCi07o7ea-LQ80GyOlMK_kbrLlTnMYAjUw",
#     "https://play-lh.googleusercontent.com/kphaelMT-6LO33pY8epzALpRB3-896dFKr_nowqzAVNzjyiizVHJesgh3nuNdwC6WA",
#     "https://play-lh.googleusercontent.com/gFHtddz7JgSyBUN7MF_2g3ZQrPG-5E0zWjcZYfJxgwxiexACUGe1_YwmlstbHBShgA",
#     "https://play-lh.googleusercontent.com/brce2mTm_GZToujS-KvoyqK0a2GKtfZGaFOo_2z0hjafehKyJYg-bbCbwFBqQcx1m1k",
#     "https://play-lh.googleusercontent.com/RR5qOs4Q1_L2-muFd63qbO32OTWOV0-x1U5HiaWSnAYNZDal5b5EY35A0pfLwDe3hw",
#     "https://play-lh.googleusercontent.com/zvpOusPc-D6ymb58Ad2CGKOaslSHLR_FGGaLKYzrt7qYNBKXIX_fSTu8p9FjRhANYBtj",
#     "https://play-lh.googleusercontent.com/QCei0XSuTJ22VGrixeEZakEgE9a9mCA83VKVDv-uqyplSr0I-6XGdK0OrgtFsSwMq4Q",
#   "title": "Flip: Bebas Biaya Transfer",
#   "updated": 1645110679,
#   "url": "https://play.google.com/store/apps/details?id=id.flip&hl=id&gl=id",
#   "version": "2.1.0",
#   "video": null,
#   "videoImage": null
# }

# %%
def format_title(title):
    sep_index = title.find(':') if title.find(':') != -1 else title.find('-')
    if sep_index != -1:
        title = title[:sep_index]
    return title[:10]

fig, axs = plt.subplots(2, len(app_infos) // 2, figsize=(14,5))

for i,ax in enumerate(axs.flat):
    ai = app_infos[i]
    img = plt.imread(ai['icon'])
    ax.imshow(img)
    ax.set_title(format_title(ai['title']))
    ax.axis('off')

# %%
app_infos_df = pd.DataFrame(app_infos)
app_infos_df
# Out:
#                         title  \
# 0  Flip: Bebas Biaya Transfer
#
#                                          description  \
# 0  <b>Transfer antarbank gratis? top up e-wallet ...
#
#                                      descriptionHTML  \
# 0  <b>Transfer antarbank gratis? top up e-wallet ...
#
#                                              summary  \
# 0  Aplikasi transfer antar bank gratis untuk bisn...
#
#                                          summaryHTML    installs  minInstalls  \
# 0  Aplikasi transfer antar bank gratis untuk bisn...  5.000.000+      5000000
#
#       score  ratings  reviews  ...     released     updated  version  \
# 0  4.662243   345662   160510  ...  10 Jan 2017  1645110679    2.1.0
#
#                                        recentChanges  \
# 0  Kakak tau gak? Flip diam-diam selalu dengerin ...
#
#                                    recentChangesHTML editorsChoice  \
# 0  Kakak tau gak? Flip diam-diam selalu dengerin ...         False
#
#                                          similarApps moreByDeveloper    appId  \
# 0  [com.telkom.mwallet, com.btpn.dc, ovo.id, id.c...            None  id.flip
#
#                                                  url
# 0  https://play.google.com/store/apps/details?id=...
#
# [1 rows x 51 columns]

# %%
app_infos_df.to_csv('apps.csv', index=None, header=True)

# %%
app_reviews = []

for ap in tqdm(app_packages):
    for score in list(range(1, 6)):
        for sort_order in [Sort.MOST_RELEVANT, Sort.NEWEST]:
              rvs, _ = reviews(
                ap,
                lang='id',
                country='id',
                sort=sort_order,
                count= 500 if score == 3 else 300,
                filter_score_with=score
              )
for r in rvs:
    r['sortOrder'] = 'most_relevant' if sort_order == Sort.MOST_RELEVANT else 'newest'
    r['appId'] = ap
app_reviews.extend(rvs)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:08<00:00, 68.08s/it]

# %%
print_json(app_reviews[0])
# Out:
# {
#   "appId": "id.flip",
#   "at": "2022-03-10 10:15:41",
#   "content": "ok",
#   "repliedAt": null,
#   "replyContent": null,
#   "reviewCreatedVersion": "2.1.0",
#   "reviewId": "gp:AOqpTOF7GWB-uzJwsmPJftAhKGK_9CJdQH6GsnUhg9rVJxFsyFocURnFRJvB1LjUYnxL-MmFcr8c580VjZbYcQ",
#   "score": 5,
#   "sortOrder": "newest",
#   "thumbsUpCount": 0,
#   "userImage": "https://play-lh.googleusercontent.com/a-/AOh14GhiAAILUVAxGb9UpQeCbSDJvSXXOAMUqMsuPuufRA",
#   "userName": "KAJI NANANG"
# }

# %%
len(app_reviews)
# Out:
# 300

# %%
app_reviews_df = pd.DataFrame(app_reviews)
app_reviews_df.to_csv('reviews.csv', index=None, header=True)
app_reviews_df
# Out:
#                                               reviewId  \
# 0    gp:AOqpTOF7GWB-uzJwsmPJftAhKGK_9CJdQH6GsnUhg9r...
# 1    gp:AOqpTOEBjnhRObXNSS8K1t9FGWyN2-fzH-qcxERILS-...
# 2    gp:AOqpTOFLcNRiQ5A1zFXcdkk1kQvwu09edJ0lgNff-ho...
# 3    gp:AOqpTOHQlP8lD_FPLI7CgSJVy8BIWGydpUVdEjHNM1v...
# 4    gp:AOqpTOFlaPVWce_U-qX0tnLM5wLY7IY5jtbb1z3hphL...
# ..                                                 ...
# 295  gp:AOqpTOFHzewv2i4E0IbOlauWkKV_NBOn78V2dbTGxEs...
# 296  gp:AOqpTOFhPgh-q9mYjB_QQlGIqRBU0uiRansKghS0Suo...
# 297  gp:AOqpTOGf4Xm5gepA-NUtHr24sYbUpIweGjBMwzOMWJ6...
# 298  gp:AOqpTOEj-6XffASoiTYCirzVA_QNW4l2uMHPYJ5uvT1...
# 299  gp:AOqpTOGJ2KALUbhRwCZPipqCXnmOlzHw0Jj31nHP0lS...
#
#                    userName  \
# 0               KAJI NANANG
# 1      Kirana Septian Dista
# 2    Pratama Friedo Saputra
# 3             harry harjito
# 4            Tjokro Diharjo
# ..                      ...
# 295          Asep Supardani
# 296           Stefania Meze
# 297            Rendi Andika
# 298         Roslina Roslina
# 299            Iwan Rahargo
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/AOh14...
# 1    https://play-lh.googleusercontent.com/a-/AOh14...
# 2    https://play-lh.googleusercontent.com/a-/AOh14...
# 3    https://play-lh.googleusercontent.com/a/AATXAJ...
# 4    https://play-lh.googleusercontent.com/a/AATXAJ...
# ..                                                 ...
# 295  https://play-lh.googleusercontent.com/a/AATXAJ...
# 296  https://play-lh.googleusercontent.com/a-/AOh14...
# 297  https://play-lh.googleusercontent.com/a-/AOh14...
# 298  https://play-lh.googleusercontent.com/a/AATXAJ...
# 299  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                content  score  thumbsUpCount  \
# 0                                                   ok      5              0
# 1    Sangat bermanfaat dan membantu aplikasi ini be...      5              0
# 2    Sangat membantu saya dalam bertransaksi perban...      5              0
# 3                                      Sangat membantu      5              0
# 4    Sangat sangat membantu proses transfer uang sa...      5              0
# ..                                                 ...    ...            ...
# 295  Aplikasi bagus banget😇, sangat membantu. Janga...      5              0
# 296  Terima kasih untuk tim dev. FLIP yang udah bua...      5             13
# 297                                             Mantap      5              0
# 298  Pertama pake u proses refund.. hanya 10 menita...      5              0
# 299                                                 Ok      5              0
#
#     reviewCreatedVersion                  at replyContent repliedAt sortOrder  \
# 0                  2.1.0 2022-03-10 10:15:41         None      None    newest
# 1                 1.31.0 2022-03-10 10:15:35         None      None    newest
# 2                  2.1.0 2022-03-10 10:08:49         None      None    newest
# 3                  2.1.0 2022-03-10 10:00:46         None      None    newest
# 4                  2.1.0 2022-03-10 09:55:37         None      None    newest
# ..                   ...                 ...          ...       ...       ...
# 295                2.1.0 2022-03-08 11:04:13         None      None    newest
# 296                2.1.0 2022-03-08 10:57:45         None      None    newest
# 297                2.1.0 2022-03-08 10:56:50         None      None    newest
# 298                 None 2022-03-08 10:45:02         None      None    newest
# 299                2.1.0 2022-03-08 10:45:01         None      None    newest
#
#        appId
# 0    id.flip
# 1    id.flip
# 2    id.flip
# 3    id.flip
# 4    id.flip
# ..       ...
# 295  id.flip
# 296  id.flip
# 297  id.flip
# 298  id.flip
# 299  id.flip
#
# [300 rows x 12 columns]
